# %%
import json
from datetime import datetime
from pysurvey.plot import setup, dateticks

# %%
filename = '/Users/ajmendez/data/batterylog/simplelog.json'
data = json.load(open(filename, 'r'))

# %%
date = [datetime.fromtimestamp(x['date']) for x in data]
cap = [x['Capacity'] for x in data]

# %%
setup(figsize=(6,6))
pylab.plot(date, cap, '.')
dateticks('%Y.%m.%d')
